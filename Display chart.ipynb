# %% [markdown]
# ## Display graph overview

# %%
import pickle

# File paths
# GRAPH_FILE = 'user_graph.pkl'
# VISITED_FILE = 'visited_users.pkl'
# QUEUE_FILE = 'user_queue.pkl'

GRAPH_FILE = 'user_graph.pkl'
BACKUP_FILE = 'user_graph_backup.pkl'
VISITED_FILE = 'visited.pkl'
QUEUE_FILE = 'queue.pkl'


# Load and display the graph data
print("=== Graph Data ===")
with open(GRAPH_FILE, 'rb') as f:
    graph = pickle.load(f)

# Check if the graph is not empty
if graph:
    for user, data in graph.items():
        print(f"User: {user}")
        print(f"  Followers Count: {data.get('followers_count', 'N/A')}")
        print(f"  Connections: {data.get('connections', [])}")
        print("-" * 40)
else:
    print("Graph is empty.")

# Load and display the visited users
print("\n=== Visited Users ===")
with open(VISITED_FILE, 'rb') as f:
    visited = pickle.load(f)

if visited:
    print(f"Total Visited Users: {len(visited)}")
    print("Visited Users List:")
    for user in visited:
        print(user)
else:
    print("No users have been visited yet.")

# Load and display the queue
print("\n=== User Queue ===")
with open(QUEUE_FILE, 'rb') as f:
    queue = pickle.load(f)

if queue:
    print(f"Users in Queue: {len(queue)}")
    print("Queue Contents:")
    for item in queue:
        print(item)
else:
    print("Queue is empty.")
# Out:
# === Graph Data ===
# User: pcayuqueo.bsky.social
#   Followers Count: 549
#   Connections: {'followers_count': 549, 'connections': ['bsky.app', 'censelio.bsky.social', 'juanarivers.bsky.social']}
# ----------------------------------------
# User: jpiquer.bsky.social
#   Followers Count: 337
#   Connections: {'followers_count': 337, 'connections': ['aoc.bsky.social', 'washingtonpost.com', 'jay.bsky.team', 'marcelias.bsky.social', 'hcrichardson.bsky.social']}
# ----------------------------------------
# User: juanseapi.bsky.social
#   Followers Count: 163
#   Connections: {'followers_count': 163, 'connections': ['bsky.app', 'aoc.bsky.social', 'theonion.com', 'jay.bsky.team', 'theguardian.com']}
# ----------------------------------------
# User: dmimica.bsky.social
#   Followers Count: 1229
#   Connections: {'followers_count': 1229, 'connections': ['theonion.com', 'nytimes.com', 'markhamillofficial.bsky.social', 'atrupar.com', 'briantylercohen.bsky.social']}
# ...
